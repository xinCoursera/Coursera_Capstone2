# %% [markdown]
# <h1>Coursera IBM Data Science </h1>
#
# <h3>Hello, congrats on making this far!</h3>
#
# Good luck and have fun!!!

# %%
## import important libraries
import numpy as np
import pandas as pd

# %%
## test print statement
print("Hello Capstone Course Project!")
# Out:
# Hello Capstone Course Project!
